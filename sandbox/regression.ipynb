# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from context import bayes_factor
from bayes_factor.bayes_factor import BayesFactor
from utils import sample_nominal, sample_numeric

# %%
n = 1000
k = 5
mu1 = 0
std1 = 1
mu2 = 2
std2 = 1
slope = 100

data, dtypes = sample_numeric(mu1, std1, n, 1)
data, dtypes = sample_numeric(mu2, std2, n, 1, data, dtypes, regressor_col='numeric_0', slope=slope)
# Out:
# /Users/bmontambault/Desktop/repos/bayes_factor/sandbox/utils.py:53: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = (data[regressor_col] * slope)[:,None]

# %%
plt.plot(data['numeric_0'], data['numeric_1'], 'bo')

# %%
bf = BayesFactor(dtypes)

# %%
bf.bayes_factor(data, 'numeric_0', 'numeric_1')
# Out:
# 4556.850194846797
